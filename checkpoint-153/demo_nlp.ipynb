# %%
import torch
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments

# %%
ds = Dataset.load_from_disk("./nlpcc_2017/")
ds
# Out:
# Dataset({
#     features: ['title', 'content'],
#     num_rows: 5000
# })

# %%
ds = ds.train_test_split(100, seed=42)
ds
# Out:
# Loading cached split indices for dataset at /mnt/workspace/nlpcc_2017/cache-1c09a3a414c6d4a6.arrow and /mnt/workspace/nlpcc_2017/cache-1de0c1dd37eb7170.arrow
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'content'],
#         num_rows: 4900
#     })
#     test: Dataset({
#         features: ['title', 'content'],
#         num_rows: 100
#     })
# })

# %%
#加载模型
# 检查是否有可用的 GPU
path='./checkpoint-153'  #模型存在的文件夹

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModelForSeq2SeqLM.from_pretrained(path,trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained(path,trust_remote_code=True)
# 将模型移动到 GPU
model.to(device)
# Out:
# GLMForConditionalGeneration(
#   (glm): GLMModel(
#     (word_embeddings): VocabEmbedding()
#     (transformer): GLMStack(
#       (embedding_dropout): Dropout(p=0.1, inplace=False)
#       (position_embeddings): Embedding(1025, 1024)
#       (block_position_embeddings): Embedding(1025, 1024)
#       (layers): ModuleList(
#         (0-23): 24 x GLMBlock(
#           (input_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attention): SelfAttention(
#             (query_key_value): Linear(in_features=1024, out_features=3072, bias=True)
#             (attention_dropout): Dropout(p=0.1, inplace=False)
#             (dense): Linear(in_features=1024, out_features=1024, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (post_attention_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (dense_h_to_4h): Linear(in_features=1024, out_features=4096, bias=True)
#             (dense_4h_to_h): Linear(in_features=4096, out_features=1024, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (final_layernorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )

# %%
import torch

model = model.eval()

def predict_test():
    predict = []
    with torch.inference_mode():
        for d in ds["test"]:
            inputs = tokenizer("摘要生成: \n" + d["content"] + tokenizer.mask_token, return_tensors="pt")
            inputs = tokenizer.build_inputs_for_generation(inputs, max_gen_length=64)
            inputs = inputs.to("cuda")
            output = model.generate(**inputs, max_new_tokens=64, eos_token_id=tokenizer.eop_token_id, do_sample=True)
            predict.append(tokenizer.decode(output[0].tolist()).split("<|startofpiece|>")[1].replace("<|endofpiece|>", "").strip())
            print("curID:", len(predict))
    return predict

# %%
import re
import torch
import jieba.posseg as posseg
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments

###################################################
# TextRank实现
###################################################
# 停用词路径
stopwords_path = './TextRank/stopwords.txt'
# 需要排除的词性
stopPOS = []

# 读取停用词
with open(stopwords_path, 'r', encoding='utf-8') as f:
    stopwords = [line.strip() for line in f.readlines()]

def segment_text_to_sentence(text):
    # 将文本分割成句子
    sentences = re.split(r'[。！？!?]', text)
    sentences = [sentence.strip().replace(" ", "").replace('\n','') for sentence in sentences if sentence.strip()]
    return sentences

def segment_text_to_words(text, use_stopwords):
    # 分词并去除停用词
    global stopPOS, stopwords
    stopPOS = [item.lower() for item in stopPOS]
    words = posseg.cut(text)
    if use_stopwords:
        words = [word for word, flag in words if flag[0].lower() not in stopPOS and word not in stopwords]
    else:
        words = [word for word, flag in words if flag[0].lower() not in stopPOS]
    words = set(words)

    return words

def original_similarity_matrix(sentences, use_stopwords):
    # 计算原始相似性矩阵
    sentence_words = [set(segment_text_to_words(item, use_stopwords)) for item in sentences]
    # print(sentence_words)
    size = len(sentences)
    similarity_matrix = np.zeros((size, size))
    for i in range(size):
        for j in range(i+1, size):
            if len(sentence_words[i]) == 0 or len(sentence_words[j]) == 0:
                similarity = 0
            else:
                # 计算相似性
                similarity = len(sentence_words[i] & sentence_words[j]) / (np.log(len(sentence_words[i])) + np.log(len(sentence_words[i])) + 1e-10)
            similarity_matrix[i][j] = similarity_matrix[j][i] = similarity
    return similarity_matrix

def cosine_tfidf_similarity_matrix(sentences, use_stopwords):
    # 计算基于TF-IDF的余弦相似性矩阵
    sentence_words = [' '.join(segment_text_to_words(item, use_stopwords)) for item in sentences]
    tfidf_vectorizer = TfidfVectorizer()
    tfidf_matrix = tfidf_vectorizer.fit_transform(sentence_words)
    similarity_matrix = cosine_similarity(tfidf_matrix)

    # 将对角线元素设置为0，避免自身与自身的相似性干扰
    np.fill_diagonal(similarity_matrix, 0)
    return similarity_matrix

def summarize_text_rank(text, d=0.85, iter_num=200, top=3, method='默认方式', use_stopwords=True):
    sentences = segment_text_to_sentence(text)

    print('---------开始----------------------------------------')
    if method == '默认方式':
        edge_weight = original_similarity_matrix(sentences, use_stopwords)
    elif method == 'TF-IDF':
        edge_weight = cosine_tfidf_similarity_matrix(sentences, use_stopwords)

    node_weight = np.ones((len(sentences)))
    # print(node_weight)
    
#     print("句子间相似性计算(边的权重)")
#     print(edge_weight)

#     print("\n句子节点参数迭代更新：")
    for num in range(iter_num):                
        # TextRank迭代公式
        # print(node_weight)
        node_weight_new = (1-d) + d * node_weight @ (edge_weight / (edge_weight.sum(axis=-1) + 1e-10)).T
        if ((node_weight_new - node_weight)**2).sum() < 1e-10:
            break
        node_weight = node_weight_new
        # print(node_weight)

    if num < iter_num:
        print('迭代{}次，收敛'.format(num))
    else:
        print('迭代{}次，未收敛'.format(num))

    sorted_indices = np.argsort(node_weight)[::-1]

    # 获取最大的几个值及其对应的索引
    top_indices = sorted(sorted_indices[:top])
    top_values = node_weight[top_indices]

    print('最大的{}个值：'.format(top), top_values)
    print('对应的索引：', top_indices)
    print('结果：')
    result = ''
    for idx in top_indices:
        result += sentences[idx] + '。\n'
    print(result)

    return result

# # # 示例
# text = '记者7日从江苏省苏州市有关部门证实,该市一名初中副校长涉嫌泄露联考考题被停职,纪委已介入调查。今年4月,苏州市吴江区举行初三联考,震泽初级中学是联考学校之一,联考成绩将直接影响考生能否进入四星级高中(即重点高中)。就在考试前一天,考卷题目已在网上疯传,引发社会关注。据知情人士介绍,疑似震泽初级中学副校长将题目提前泄露给自己亲戚,然后这位亲戚又将题目进行了散播,导致题目最终被传到了网上。据苏州市吴江区教育局副局长沈正元介绍,泄题事件发生后,教育局于5月紧急推出了学校自主招生考试政策,以弥补泄题造成的不良后果。5月11日,教育局对涉嫌泄题违纪的震泽初级中学副校长作出停职处理,区纪委也已介入调查,教育部门会根据纪委处理意见进行相应处理。另据家长反映,泄题事件中一些“得题考生”出现在了震泽中学的保送名单里。对此,沈正元回应称,目前对涉嫌的涉事成年人进行了初步处理,纪委尚未作出明确处理意见,所以推优、自主招生等还按正常程序进行,因此出现了市民反映的疑似“得题考生”出现在名单中的情况。具体处理意见将在调查结果公布后作出,教育局将尽快进行相关调查工作,保障学生正当利益。(记者刘巍巍'
# summarize_text_rank(text)

# %%
import torch

def predict_test():
    predict = []
    with torch.inference_mode():
        for d in ds["test"]:
            output=summarize_text_rank(d["content"], d=0.85, iter_num=200, top=1, method='默认方式', use_stopwords=True)
            predict.append(output)
            print("curID:", len(predict))
    return predict

# %%
result = predict_test()
# Out:
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.25248288]
# 对应的索引： [6]
# 结果：
# 英国《卫报》引述电脑安全专家亨特的话说,IS的说法或许危言耸听,因为该组织即便手中有资料,有可能也是早前因为各种不慎方式外泄的,未必是IS旗下黑客获得的,所以“有造假嫌疑”。
#
# curID: 1
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.35559688]
# 对应的索引： [0]
# 结果：
# 中新网5月27日电据中共安徽省纪律检查委员会网站消息,日前,安徽宿松县招商局副局长李同保、交通运输局下属道路运输管理局副局长余刚涉嫌吸食毒品被开除党籍、行政撤职,宿松县纪委对县招商局、县交通运输局给予全县通报批评。
#
# curID: 2
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.25691131]
# 对应的索引： [0]
# 结果：
# 新华网哈尔滨4月9日电(记者梁书斌)记者在黑龙江省公安厅了解到,非法生产、销售和使用“伪基站”设备违法犯罪活动日益突出。
#
# curID: 3
# ---------开始----------------------------------------
# 迭代14次，收敛
# 最大的1个值： [1.24157269]
# 对应的索引： [0]
# 结果：
# 从明天开始,北京市将实行新一轮机动车尾号轮换。
#
# curID: 4
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.2476539]
# 对应的索引： [0]
# 结果：
# 21日9时20分许,在哈市松北区松北一路55号一家宾馆门前人行道上,一名中年男子由于有外遇多天不回家,他的母亲与妻子找到他后,三人厮打在一起。
#
# curID: 5
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.58356051]
# 对应的索引： [5]
# 结果：
# 5月11日,教育局对涉嫌泄题违纪的震泽初级中学副校长作出停职处理,区纪委也已介入调查,教育部门会根据纪委处理意见进行相应处理。
#
# curID: 6
# ---------开始----------------------------------------
# 迭代15次，收敛
# 最大的1个值： [1.36069821]
# 对应的索引： [0]
# 结果：
# 新华网石家庄1月18日电(记者齐雷杰、巩志宏)记者从河北省承德市纪委获悉,承德市2名处级干部严重违纪被开除党籍、开除公职,其涉嫌犯罪问题及线索移送司法机关依法处理。
#
# curID: 7
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [2.14300349]
# 对应的索引： [1]
# 结果：
# 李佩斯写中文向微博网友问好在《霍比特人》中美得不可方物的李佩斯新浪娱乐讯美国男演员李·佩斯近日开通微博,今天(5月19日)上午,李·佩斯贴出一张自己的照片向网友们问好。
#
# curID: 8
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.46374683]
# 对应的索引： [2]
# 结果：
# 据英国《阿拉伯人报》8月3日报道,“伊斯兰国”组织控制了伊拉克北部和叙利亚东北部一些粮食作物产区,已攫取了100多万吨小麦,约占伊拉克年消费量的1/5。
#
# curID: 9
# ---------开始----------------------------------------
# 迭代36次，收敛
# 最大的1个值： [1.31124095]
# 对应的索引： [3]
# 结果：
# 1.政府及相关部门按照职责做好防大风工作;2.停止露天活动和高空等户外危险作业,危险地带人员和危房居民尽量转到避风场所避风;3.相关水域水上作业和过往船舶采取积极的应对措施,加固港口设施,防止船舶走锚、搁浅和碰撞;4.切断户外危险电源,妥善安置易受大风影响的室外物品,遮盖建筑物资;5.机场、高速公路等单位应当采取保障交通安全的措施,有关部门和单位注意森林、草原等防火。
#
# curID: 10
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.50673202]
# 对应的索引： [2]
# 结果：
# 他说,上海25年来的发展,是中国改革开放的一个缩影,相信昂山主席此次访问中国、访问上海,会更加深入地了解改革开放以来中国的巨大变化,促进中缅双方的友好交流合作。
#
# curID: 11
# ---------开始----------------------------------------
# 迭代6次，收敛
# 最大的1个值： [1.40311952]
# 对应的索引： [0]
# 结果：
# “三湘第一寿星”田龙玉“三湘第一寿星”田龙玉红网凤凰站讯1893年6月9日出生,今年122岁了。
#
# curID: 12
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.51510631]
# 对应的索引： [0]
# 结果：
# 中新网7月23日电拱墅区人民政府大关街道办事处今天通报“杭州市拱墅区大关街道一名正科级干部包某被举报涉嫌强奸他人并与他人通奸”一事进展,决定给予包志平开除党籍、行政撤职处分。
#
# curID: 13
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.32290592]
# 对应的索引： [6]
# 结果：
# 旅客携带出境的黄金及其制品超过自用合理数量的,须以货物出口方式报关出口,海关凭中国人民银行总行或其授权的中国人民银行分支机构签发的《中国人民银行黄金及其制品进出口准许证》办理验放手续。
#
# curID: 14
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.39457497]
# 对应的索引： [0]
# 结果：
# 图为“招聘”女友引来不少人围观通讯员焦姣摄本报讯(记者李爱华屈建成通讯员焦姣彭青云)昨天,网友发微博称:在华中科技大学武昌分校西区广场,一名男青年摆摊招聘女友。
#
# curID: 15
# ---------开始----------------------------------------
# 迭代18次，收敛
# 最大的1个值： [1.19983903]
# 对应的索引： [1]
# 结果：
# 图例标准防御指南预计未来24小时内可能出现下列条件之一并将持续或实况已达到下列条件之一并可能持续:能见度小于3000米且相对湿度小于80%的霾;能见度小于3000米且相对湿度大于等于80%,PM2.5浓度大于115微克/立方米且小于等于150微克/立方米:能见度小于5000米,PM2.5浓度大于150微克/立方米且小于等于250微克/立方米。
#
# curID: 16
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.6278959]
# 对应的索引： [4]
# 结果：
# 查看原文(中新网)>>【古力娜扎晒家人合影姐姐撞脸黄磊娇妻】今日(2月26日),古力娜扎晒出两张与姐姐的合影,网友纷纷调侃姐姐是黄磊娇妻孙莉。
#
# curID: 17
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.1975933]
# 对应的索引： [2]
# 结果：
# ”邓东成家住胶东半岛莱州市三山岛街道后邓村,退伍还乡的他发现在农村开发光伏能源有许多优势,还能得到国家政策的支持,于是决定在自家屋顶建一个50千瓦的光伏发电系统。
#
# curID: 18
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.55602624]
# 对应的索引： [7]
# 结果：
# 而昨日正当家人以为孩子被人拐骗时,噩耗传来:姐姐高宇萱的尸体在村子附近的河里被人发现。
#
# curID: 19
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.06753899]
# 对应的索引： [0]
# 结果：
# 新华网郑州6月21日电(记者宋晓东)记者日前从郑州市住房保障与房地产管理局获悉,5月份,郑州市商品住宅销售均价达10243元/平方米,涨幅29.04%,郑州市商品住宅均价首次突破万元。
#
# curID: 20
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.29160097]
# 对应的索引： [2]
# 结果：
# 英特尔这次发行债劵所筹集的资金将会部分注资到他们167亿美元的Altera收购案上。
#
# curID: 21
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.39128722]
# 对应的索引： [0]
# 结果：
# “你把我灌醉,你让我流泪……”安徽舒城的王先生就遭遇了人生中最痛苦的事情:被妻子算计,还被自己同事成功“挖墙脚”,王先生愤怒地起诉离婚。
#
# curID: 22
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.42450136]
# 对应的索引： [0]
# 结果：
# 中国新闻网2014-08-2518:25:03中新网南昌8月25日电(记者王剑)江西省纪委监察厅网站25日消息,瑞昌市政协党组成员、政协副主席徐新民涉嫌严重违纪,目前正接受组织调查。
#
# curID: 23
# ---------开始----------------------------------------
# 迭代7次，收敛
# 最大的1个值： [1.26653374]
# 对应的索引： [4]
# 结果：
# 衡阳市公安局指挥中心立即组织民警赶赴南华附一医院,并安排民警与曹某联系,询问炸弹的安放地点。
#
# curID: 24
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.24603169]
# 对应的索引： [6]
# 结果：
# ”住管局副局长曹某称,当时3名女业主并不是向他下跪,他也并没有置之不理,而是始终对业主笑脸相迎。
#
# curID: 25
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.45828881]
# 对应的索引： [0]
# 结果：
# 现场图现场图楚天都市报6月1日快讯(记者李丽)家住梁子湖区的鲁先生向楚天都市报记者独家报料,近几日梁子湖湖边忽然涌现大量乌龟,其中不少乌龟上岸后死亡。
#
# curID: 26
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.43787116]
# 对应的索引： [0]
# 结果：
# 中新网唐山10月27日电(记者白云水)据中国地震台网消息,河北省唐山市开平区、古冶区交界27日凌晨3点32分发生3.3级地震,巧合的是,此次地震与发生在1976年的7.8级唐山大地震时间仅相差10分钟。
#
# curID: 27
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.20913428]
# 对应的索引： [2]
# 结果：
# 中央气象台消息,5月1日至5月2日,我国将出现一次较大范围降雨天气过程,其中四川盆地、江南、华南北部等地的部分地区有大雨,局地有暴雨。
#
# curID: 28
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.46528889]
# 对应的索引： [1]
# 结果：
# 中新网7月12日电据美联社报道,墨西哥安全部门于当地时间11日发表了一项声明称,该国头号大毒枭,绰号“矮子”古斯曼于前一晚从一座看守最为严格的监狱中,越狱逃跑。
#
# curID: 29
# ---------开始----------------------------------------
# 迭代20次，收敛
# 最大的1个值： [1.50232123]
# 对应的索引： [5]
# 结果：
# 1.政府及农林主管部门按照职责做好防霜冻应急工作;2.农村基层组织要广泛发动群众,防灾抗灾;3.对农作物、林业育种要积极采取田间灌溉等防霜冻、冰冻措施,尽量减少损失;4.对蔬菜、花卉、瓜果要采取覆盖、喷洒防冻液等措施,减轻冻害。
#
# curID: 30
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.74616732]
# 对应的索引： [7]
# 结果：
# 经初步商议,中船重工和公司拟分别以其持有的动力相关资产(股权)参与风帆股份的重大资产重组,涉及的资产范围尚未最终确定。
#
# curID: 31
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.2014683]
# 对应的索引： [1]
# 结果：
# 5月14日晚上8点多,盐城大丰市川东乡李阳(化名)在川东的一家饭店和几位朋友一起喝酒,酒过三巡,居然跑到了情人家里,结果被情人的丈夫发觉,两人发生矛盾,他被砍入院。
#
# curID: 32
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.49378469]
# 对应的索引： [4]
# 结果：
# 他说,“相比此前的发现,这次发现的开普勒452b行星所围绕的那颗恒星是与太阳最相似的一颗,因此开普勒452b的环境与地球相似的机会还是比较大的。
#
# curID: 33
# ---------开始----------------------------------------
# 迭代15次，收敛
# 最大的1个值： [1.67444052]
# 对应的索引： [3]
# 结果：
# 28日晚到29日白天,盆地各市阴天有雷雨或阵雨,西部和西北部大雨,广元、绵阳、德阳、成都、雅安、眉山6市的部分地方有暴雨,局部大暴雨;阿坝州东部局地有中雨。
#
# curID: 34
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.22525285]
# 对应的索引： [4]
# 结果：
# 在过去12个月的时间里,中国股市市值增加了6.7万亿美元,这一增加值超过了除美国外的任一国家股市的总市值。
#
# curID: 35
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.20413034]
# 对应的索引： [0]
# 结果：
# 新华网开罗6月15日电(记者刘万利商英侠)萨那消息:也门安全官员15日说,“基地”组织阿拉伯半岛分支最高头目纳赛尔·武海希已经被美军无人机击毙。
#
# curID: 36
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.31833305]
# 对应的索引： [2]
# 结果：
# 李密摄图为灭火后的酒吧,窗户玻璃已被大火烧掉一半。
#
# curID: 37
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.46873719]
# 对应的索引： [3]
# 结果：
# 据新浪财经了解,针对“10罐7罐”广告纠纷,王老吉与加多宝已相继在重庆、长沙、广州等三地对簿公堂,目前除长沙一审尚未宣判外,其他两起诉讼目前均为王老吉胜诉。
#
# curID: 38
# ---------开始----------------------------------------
# 迭代70次，收敛
# 最大的1个值： [1.80267147]
# 对应的索引： [1]
# 结果：
# --PGC_VIDEO:{"status":0,"thumb_height":"300","thumb_url":"7204/7244118145","vid":null,"thumb_width":"400","sp":"toutiao","uri":"21933/7851972932","vu":"631bdaa6d6cf4079838bcdb4765a342c","web_uri":"7204/7244118145","duration":197.0,"group_id":"5376458847","store_id":7753010}--}您的浏览器不支持video标签。
#
# curID: 39
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.60761985]
# 对应的索引： [3]
# 结果：
# 龙骧出租车分公司的客服主任王主任对记者表示,公司对这件事高度重视,只是现在出租行业套牌现象很多,暂时不能确定这台的士是否是套用了龙骧出租车分公司的车牌。
#
# curID: 40
# ---------开始----------------------------------------
# 迭代15次，收敛
# 最大的1个值： [1.57424648]
# 对应的索引： [0]
# 结果：
# 原湖北省国资委副主任鲁力军荆楚网讯据湖北省纪委监察厅网站消息,经中共湖北省委组织部证实,鲁力军因涉嫌严重违纪,省委已决定免去其省政府国有资产监督管理委员会副主任、党委委员,湖北清能地产集团公司党委书记、委员职务,现正按有关规定办理。
#
# curID: 41
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.38442097]
# 对应的索引： [6]
# 结果：
# 这17个问题涉及环境、政府和经济三方面,而中国在这些问题上的得分都远低于国际水平和日本。
#
# curID: 42
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.53477186]
# 对应的索引： [6]
# 结果：
# 此外,教育部将加快巡视频率,扩大巡视范围,全年拟派出20个巡视组,采取常规巡视和专项巡视相结合,实现直属高校、直属单位和驻外教育机构巡视的全覆盖。
#
# curID: 43
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.44605929]
# 对应的索引： [4]
# 结果：
# 大名单公示如下:广州恒大:曾诚于汉超张琳芃郑智黄博文梅方郜林冯潇霆郑龙邹正王上源山东鲁能:王大雷王彤刘彬彬王永珀蒿俊闵杨旭北京国安:朴成张池明雷腾龙杨智张稀哲于大宝河南建业:毕津浩广州富力:刘殿座金洋洋于洋姜至鹏贵州人和:饶伟辉辽宁宏运:杨超声江苏舜天:任航吴曦李昂刘建业吉翔孙可上海申花:高迪上海上港:颜骏凌武磊于海王燊超蔡慧康巴列卡诺;张呈栋杭州绿城:冯刚谢鹏飞国家队教练组将根据以上运动员近期在联赛中的综合评定结果,研究确定国家队集训23人名单。
#
# curID: 44
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.29657642]
# 对应的索引： [2]
# 结果：
# 一个多月前,记者深入大凉山,近距离接触了许多如苦依五木般的孩子。
#
# curID: 45
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.23155144]
# 对应的索引： [0]
# 结果：
# 新华网郑州2月23日电(记者李鹏)记者从有关部门获悉,三门峡市原市委常委、副市长张英焕因受贿700余万元,被许昌市中级人民法院一审判处有期徒刑14年。
#
# curID: 46
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.27092161]
# 对应的索引： [5]
# 结果：
# SPDRGoldTrust持有的资产周一跌到2008年9月19日以来最低水平,基金经理持有的黄金淨多单降至2006年美国政府开始追踪数据以来的最低点。
#
# curID: 47
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.63909917]
# 对应的索引： [5]
# 结果：
# ”《江南都市报》报道,在首发式暨签售活动中,黄天文透露,写书的初衷是想圆王军霞一直想写自传而又未能实现的愿望,“当初这么做是想挽救我们的婚姻”。
#
# curID: 48
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.62040416]
# 对应的索引： [4]
# 结果：
# “(Adani)正在与软银谈判,他们也在与鸿海富士康谈判。
#
# curID: 49
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.22529764]
# 对应的索引： [1]
# 结果：
# 据悉,成都地铁五号线将分两期开建,计划于2019年实现一、二期工程同步开通运营。
#
# curID: 50
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.33247447]
# 对应的索引： [4]
# 结果：
# 3月5日晚嫌疑人常某一行八人在KTV唱歌后回宾馆的路上,与陌生男子发生争执,常某他们仗着人多将陌生男子打伤。
#
# curID: 51
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.211398]
# 对应的索引： [0]
# 结果：
# 中国证券网讯南非将在本月份启动国内投资达千亿美元的核电项目的国际招标程序,而进军该市场的参与者中也有中国核电企业的身影。
#
# curID: 52
# ---------开始----------------------------------------
# 迭代6次，收敛
# 最大的1个值： [1.34692576]
# 对应的索引： [1]
# 结果：
# 圆通方面相关负责人表示,起火的是圆通位于天津的一个投递点的仓库,目前圆通已经积极与客户联系进行赔偿。
#
# curID: 53
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.15438022]
# 对应的索引： [8]
# 结果：
# 张某来后,他说起妻子与张某QQ聊天内容的事情,随后双方发生争执,他拿出刀向张某连捅两刀,张某中刀后,试图驾车逃跑,但是车开出30米就没了动静。
#
# curID: 54
# ---------开始----------------------------------------
# 迭代6次，收敛
# 最大的1个值： [1.16520294]
# 对应的索引： [1]
# 结果：
# 丁一汇介绍,近几十年来全球共发生三次“超级厄尔尼诺”,分别为1972年、1982年与1997、1998年。
#
# curID: 55
# ---------开始----------------------------------------
# 迭代33次，收敛
# 最大的1个值： [1.65308506]
# 对应的索引： [0]
# 结果：
# 据中央纪委监察部网站消息,日前,中共浙江省纪委对金华新兴产业集聚区管委会原主任(副厅长级)陈陆一的严重违纪问题进行了立案检查。
#
# curID: 56
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.44392736]
# 对应的索引： [3]
# 结果：
# 报道称,本次上拍的水彩画和素描创作于1914—1922年间,多数作品都留有希特勒的签名,并被收录于他的作品集中。
#
# curID: 57
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.49421509]
# 对应的索引： [1]
# 结果：
# 爆料者称,在事故发生后不久,另一架直升飞机赶到现场,运送4名伤员离开,还有一名伤员被当地120接走。
#
# curID: 58
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.14884256]
# 对应的索引： [4]
# 结果：
# ”扬州市委书记谢正义表示,毫不手软严惩腐败堕落,对腐败“零容忍”,对于发现的腐败线索认真追查,决不含糊、决不手软、决不姑息。
#
# curID: 59
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.17205902]
# 对应的索引： [2]
# 结果：
# 为适应国家改革开放和现代化建设的需要,我国从2004年8月开始实施《外国人在中国永久居留审批管理办法》,即中国的“绿卡”制度。
#
# curID: 60
# ---------开始----------------------------------------
# 迭代17次，收敛
# 最大的1个值： [1.66846207]
# 对应的索引： [1]
# 结果：
# 磨盘村发现的东夏国遗址新浪娱乐讯流行一时的“盗墓小说”《鬼吹灯》、《盗墓笔记》中,都提到过东北长白山中有个神秘的“东夏国”。
#
# curID: 61
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.5143055]
# 对应的索引： [2]
# 结果：
# 新华社/路透参考消息网4月11日报道法新社4月11日报道称,美国总统奥巴马和古巴领导人劳尔·卡斯特罗周五在美洲峰会上见面,互相问候并握手,这标志着其外交解冻一个新的里程碑。
#
# curID: 62
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.40556181]
# 对应的索引： [0]
# 结果：
# 【环球网综合报道】日本《产经新闻》8月15日报道称,经日方海上保安厅巡逻船确认,15日当天有3艘中国海警船在钓鱼岛周边毗邻水域巡航。
#
# curID: 63
# ---------开始----------------------------------------
# 迭代15次，收敛
# 最大的1个值： [1.96313246]
# 对应的索引： [2]
# 结果：
# 据当地公安交管部门介绍,10日18时30分许,甘肃省天水市秦州区秦岭乡附近,一辆无牌无证三轮摩托车行驶途中与相向行驶的一辆大型货车发生碰撞,致三轮摩托车上人员4人当场死亡,4人受伤。
#
# curID: 64
# ---------开始----------------------------------------
# 迭代7次，收敛
# 最大的1个值： [1.33693736]
# 对应的索引： [5]
# 结果：
# 中国警方向洛佩斯的家人证实,她因走私毒品而被捕。
#
# curID: 65
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.14956821]
# 对应的索引： [2]
# 结果：
# 经调查取证,公安机关依法对邓某、王某、郝某等10名在网上编造散布涉军谣言人员,分别作出行政拘留和教育训诫处理,邓某等人对编造传播谣言的事实供认不讳,对违法行为表示悔过。
#
# curID: 66
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.40089717]
# 对应的索引： [5]
# 结果：
# 查看原文(新浪娱乐)>>32岁主持边策涉毒坠亡,好友悼念"来世不要再走错"昨天,“平安北京”在微博通报称,一名涉毒嫌疑人在警方上门调查时坠楼身亡。
#
# curID: 67
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.22142304]
# 对应的索引： [0]
# 结果：
# 中新网5月15日电据外媒15日报道,英国国防部称,因为两架俄罗斯军机“飞向英国领空”,英国皇家空军的台风战斗机紧急起飞拦截。
#
# curID: 68
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.63912635]
# 对应的索引： [5]
# 结果：
# 查看原文(新浪网)【全智贤健身房被偷拍“千颂伊”上身】据香港媒体报道,“千颂伊”全智贤凭影电视剧《来自星星的你》而红遍亚洲,更成为粉丝们天天追逐的热门对象。
#
# curID: 69
# ---------开始----------------------------------------
# 迭代14次，收敛
# 最大的1个值： [1.49291962]
# 对应的索引： [3]
# 结果：
# 黄奕声明全文:致所有的朋友:2014年10月10日,我与黄毅清先生经法院调解正式离婚。
#
# curID: 70
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.43688266]
# 对应的索引： [2]
# 结果：
# 据介绍,黑龙江科技大学按照《普通高等学校本科专业设置管理规定》要求,按照校内审议、校内公示、网络申报、高校报送材料的申报程序,开展了对此次新增专业的相关申报工作,学校确定申报投资学和机械工艺技术2个新专业,并向上级部门报送了相关材料。
#
# curID: 71
# ---------开始----------------------------------------
# 迭代14次，收敛
# 最大的1个值： [1.1757439]
# 对应的索引： [1]
# 结果：
# 图例标准防御指南预计未来24小时内可能出现下列条件之一并将持续或实况已达到下列条件之一并可能持续:能见度小于2000米且相对湿度小于80%的霾;能见度小于2000米且相对湿度大于等于80%,PM2.5浓度大于150微克/立方米且小于等于250微克/立方米;能见度小于5000米,PM2.5浓度大于250微克/立方米且小于等于500微克/立方米。
#
# curID: 72
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.42872353]
# 对应的索引： [8]
# 结果：
# 3月21日10时37分,中国平煤神马集团位于河南汝州市的梨园矿长虹公司发生一起重大煤与瓦斯突出事故,造成13名矿工遇难;3月27日11时18分,河南能源化工集团位于河南义马市的义煤公司千秋煤矿发生冲击地压事故,造成6名矿工遇难。
#
# curID: 73
# ---------开始----------------------------------------
# 迭代11次，收敛
# 最大的1个值： [1.32478054]
# 对应的索引： [5]
# 结果：
# 据了解,王某是一名女生,平时喜欢夜间开台灯上网,影响了其他室友休息,同宿舍的张某、李某对王某提出意见,双方发生矛盾,王某对张某、李某心怀不满,打算报复她们,于是到学校门口超市买来一袋樟脑丸,后趁室友上课宿舍无人时,分别将樟脑丸投进张某和李某的开水瓶及零食罐内。
#
# curID: 74
# ---------开始----------------------------------------
# 迭代16次，收敛
# 最大的1个值： [1.69261057]
# 对应的索引： [4]
# 结果：
# 13时10分,郑州警方发布情况通报称,5月8日13时08分许,郑州市公安局110指挥中心接报警,天明路生产路附近一女子被砍,民警迅速赶到现场处置。
#
# curID: 75
# ---------开始----------------------------------------
# 迭代16次，收敛
# 最大的1个值： [1.8065013]
# 对应的索引： [1]
# 结果：
# 据市公安局蕉城分局交管大队通报称,8月11日上午7时57分许,驾驶人郑某某(男,加拿大籍),驾驶小车,驾乘人员共六人,其中一名系怀抱婴儿,沿304省道宁古路由西往东行驶,经东胡隧道内(10KM+300M),与相向由李某某驾驶的市货运分公司所属重型半挂货车交会,并发生碰撞,造成小车上驾乘人员三死三伤,死者系两名男性与一名怀抱婴幼儿。
#
# curID: 76
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.46196087]
# 对应的索引： [3]
# 结果：
# 研究小组设想,如果把这种纸制电池与简单的电子回路组合在一起,垫到老人内衣中,一旦老人出现尿失禁,就可以成为一个无线传感器通知护理人员,从而大大降低护理人员巡回检查的工作量。
#
# curID: 77
# ---------开始----------------------------------------
# 迭代31次，收敛
# 最大的1个值： [1.66363858]
# 对应的索引： [1]
# 结果：
# 根据最新气象资料分析,预计今天白天我市大部地区最高气温仍将超过38℃,其中仁和区、西区局部地区将达40℃以上,我台5月26日10时20分发布的高温橙色预警信号继续有效,请做好防暑降温工作。
#
# curID: 78
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.32162587]
# 对应的索引： [4]
# 结果：
# 由于开奖之后大奖得主始终没有到省福彩中心兑付该注大奖,自2015年2月3日起,省福彩中心就连续在相关媒体上发布文章呼吁广大彩民相互提醒,希望中奖彩民及时前来领奖。
#
# curID: 79
# ---------开始----------------------------------------
# 迭代14次，收敛
# 最大的1个值： [1.08594176]
# 对应的索引： [0]
# 结果：
# 发布日期:2014-12-0921:20:48【字体:】莆田市气象台12月9日21时20分继续发布大风黄色预警信号:受冷空气影响,预计今天夜里我市沿海东北风7~8级阵风9级,请轮渡码头、出海船只、海上作业人员注意安全。
#
# curID: 80
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.29996659]
# 对应的索引： [5]
# 结果：
# 7月1日,当事人薄玉龙接受记者采访回应称,他确实被处以党内严重警告处分,并被免去职务。
#
# curID: 81
# ---------开始----------------------------------------
# 迭代7次，收敛
# 最大的1个值： [1.26977613]
# 对应的索引： [8]
# 结果：
# 民警张岳、王伟表示,这辆比亚迪一年多来总共有66次违法行为,其中60次都是超速。
#
# curID: 82
# ---------开始----------------------------------------
# 迭代14次，收敛
# 最大的1个值： [1.51128247]
# 对应的索引： [0]
# 结果：
# 【环球时报综合报道】法新社26日援引喀麦隆国家电视台的报道称,25日晚,一名12岁女孩在该国北部城市马鲁阿一家餐馆发动自杀式炸弹袭击,造成至少21人死亡、67人受伤。
#
# curID: 83
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.37141745]
# 对应的索引： [3]
# 结果：
# 民警悄悄靠过去发现,一个妖艳的“女子”和一位男子正在行不雅事。
#
# curID: 84
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.43703171]
# 对应的索引： [8]
# 结果：
# @交通银行电子银行小鱼儿努力爱生活:交通银行上海多个地点ATM机不出钞,但扣钱成功,客服电话忙音占线,支行周日休息什么情况。
#
# curID: 85
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.26747114]
# 对应的索引： [5]
# 结果：
# 之后,聂英以该商品房买卖合同所约定的定西市陇西县翡翠新城1110—1116号商铺作为抵押,与兰州市七里河区一小额贷款公司签订借款合同及房产抵押合同。
#
# curID: 86
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.29074182]
# 对应的索引： [0]
# 结果：
# 2015-04-2917:56新浪体育显示图片罗本赛季报销北京时间4月29日,拜仁官方宣布球队核心罗本由于左腿肌肉撕裂,将无缘本赛季剩余比赛,而莱万遭遇颌骨和鼻梁骨折,并伴有轻微脑震荡,可能会缺战下周和巴萨的欧冠半决赛。
#
# curID: 87
# ---------开始----------------------------------------
# 迭代16次，收敛
# 最大的1个值： [1.5982894]
# 对应的索引： [0]
# 结果：
# 标题:中国向美国提供追捕贪官“优先名单”:人都在美国(您是本帖第22个阅读者|本帖回复:2)我的红豆村最高检察院反贪总局局长徐进辉透露,中美将就海外追逃加强合作,目前中方已经向美国提供了一份追逃“优先名单”,请求美方协助追捕,据信名单上的人都藏匿在美国。
#
# curID: 88
# ---------开始----------------------------------------
# 迭代7次，收敛
# 最大的1个值： [1.37451667]
# 对应的索引： [0]
# 结果：
# 秦楚网吴楠段吉雄兰海燕郧县80后男子何某酒后和父亲发生争吵,进而在打斗中掐死父亲,并进行焚尸伪造现场。
#
# curID: 89
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.50042276]
# 对应的索引： [2]
# 结果：
# 据外媒对中联油交易员的调查显示,中国联合石油本月在新加坡交易平台上购买了48船(即2400万桶)定于6月交割的原油。
#
# curID: 90
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.38942301]
# 对应的索引： [0]
# 结果：
# 【环球网综合报道】据俄新社2月7日消息,英国首相卡梅伦发表演讲称,苏格兰威士忌是维护英国统一的基础。
#
# curID: 91
# ---------开始----------------------------------------
# 迭代7次，收敛
# 最大的1个值： [1.20283973]
# 对应的索引： [1]
# 结果：
# 据美联社11月20日报道,朝鲜方面称此决议的通过是美国的恶意推动。
#
# curID: 92
# ---------开始----------------------------------------
# 迭代12次，收敛
# 最大的1个值： [1.70116997]
# 对应的索引： [7]
# 结果：
# 李先生称,妻子是一家产品检测公司的员工,事发时她和该公司另一名女员工在出差,乘坐一辆外租面包车经过华快三期永泰至嘉禾段时发生车祸。
#
# curID: 93
# ---------开始----------------------------------------
# 迭代15次，收敛
# 最大的1个值： [1.48300635]
# 对应的索引： [3]
# 结果：
# 橘子君被照片中馨爷的美貌折服了,馨爷,哦不,是甜馨女神,夕阳西下,身着小花裙,安静地做着一位美少女,对着镜头后的妈妈,毫无忌惮地展现小孩子最纯真的面貌,和在外人面前不同,甜馨现在是处于最舒适的状态。
#
# curID: 94
# ---------开始----------------------------------------
# 迭代13次，收敛
# 最大的1个值： [1.58078015]
# 对应的索引： [0]
# 结果：
# 双头三眼小猪挺精神实习记者陈丹娅摄6月30日,洛南县城关镇王院村汤师傅家的母猪产下一头两个脑袋三只眼的白色猪崽,古怪的相貌引来左邻右舍的围观。
#
# curID: 95
# ---------开始----------------------------------------
# 迭代20次，收敛
# 最大的1个值： [1.51820453]
# 对应的索引： [2]
# 结果：
# 2102年3月吴宗宪因投资LED节能產业阿尔发光子科技公司,不但亏损连连,还被检调查出涉嫌和上柜公司联明行动科技董座许丰扬勾结,利用假交易共同掏空联明3250万元资產,遭最最重可处10年徒刑的《证券交易法》业务侵占等罪起诉。
#
# curID: 96
# ---------开始----------------------------------------
# 迭代8次，收敛
# 最大的1个值： [1.23410955]
# 对应的索引： [1]
# 结果：
# 8月6日下午,惠州机场对一名准备前往成都的中国籍女子进行身份证件查验时,发现其所持证件中的照片与本人不太相像,于是立即向惠州公安部门汇报。
#
# curID: 97
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.46231746]
# 对应的索引： [0]
# 结果：
# 2015-05-0108:29环球时报显示图片据日本《产经新闻》18日报道,日本宇宙航空开发机构(JAXA)制定了2018年发射首个月球探测器的方针。
#
# curID: 98
# ---------开始----------------------------------------
# 迭代9次，收敛
# 最大的1个值： [1.36346336]
# 对应的索引： [1]
# 结果：
# 落水女子所骑摩托中国江西网讯汪生钦、记者孙娟报道:5月26日13时30分许,赣州龙南县新华村一名女子骑摩托车通过积满水的马路时不慎跌入路旁的河道内。
#
# curID: 99
# ---------开始----------------------------------------
# 迭代10次，收敛
# 最大的1个值： [1.30848915]
# 对应的索引： [0]
# 结果：
# 中国证券网讯(记者严政)中国重工6月14日晚间公告称,公司日前接到控股股东中国船舶重工集团公司(简称“中船重工”)通知,中船重工拟对其自身相关业务进行调整,部分业务涉及到公司。
#
# curID: 100

# %%
from rouge_chinese import Rouge

rouge = Rouge()

docode_preds = [" ".join(p) for p in result]
decode_labels = [" ".join(l) for l in ds["test"]["title"]]

scores = rouge.get_scores(docode_preds, decode_labels, avg=True)
{
    "rouge-1": scores["rouge-1"]["f"],
    "rouge-2": scores["rouge-2"]["f"],
    "rouge-l": scores["rouge-l"]["f"],
}
# Out:
# {'rouge-1': 0.37328073426616526,
#  'rouge-2': 0.19245568474548322,
#  'rouge-l': 0.2647670612629381}

# %%
from rouge_chinese import Rouge

rouge = Rouge()

docode_preds = [" ".join(p) for p in result]
decode_labels = [" ".join(l) for l in ds["test"]["title"]]

                
# 计算 ROUGE 分数
scores = rouge.get_scores(docode_preds, decode_labels, avg=True)

# 提取 ROUGE 的 Precision、Recall 和 F1 值
rouge_scores = {
    "rouge-1": {
        "precision": scores["rouge-1"]["p"],
        "recall": scores["rouge-1"]["r"],
        "f1": scores["rouge-1"]["f"]
    },
    "rouge-2": {
        "precision": scores["rouge-2"]["p"],
        "recall": scores["rouge-2"]["r"],
        "f1": scores["rouge-2"]["f"]
    },
    "rouge-l": {
        "precision": scores["rouge-l"]["p"],
        "recall": scores["rouge-l"]["r"],
        "f1": scores["rouge-l"]["f"]
    }
}
print(rouge_scores)
# Out:
# {'rouge-1': {'precision': 0.3244275550696497, 'recall': 0.47781737479872033, 'f1': 0.37328073426616526}, 'rouge-2': {'precision': 0.16283231279520569, 'recall': 0.2599414846079348, 'f1': 0.19245568474548322}, 'rouge-l': {'precision': 0.22318594032682315, 'recall': 0.36696002318302595, 'f1': 0.2647670612629381}}

# %%
from bert_score import BERTScorer
from rouge import Rouge
from transformers import BertTokenizer, BertForMaskedLM
from bert_score import BERTScorer
import jieba

model_name = 'bert-base-chinese'
tokenizer_A = BertTokenizer.from_pretrained(model_name)
model_A = BertForMaskedLM.from_pretrained(model_name)

# 初始化BERTScorer
scorer = BERTScorer(model_type=model_name, num_layers=model_A.config.num_hidden_layers)

# 存储每个样本的BERTScore结果
bert_scores = []
# ds["test"]["title"]
for pred, ref in zip(result, ds["test"]["title"]):
    P, R, F1 = scorer.score([pred], [ref])
    # 存储Precision、Recall和F1值
    bert_scores.append({
        "bert-precision": P.item(),
        "bert-recall": R.item(),
        "bert-f1": F1.item()
    })
# 计算平均BERTScore的Precision、Recall和F1值
avg_precision = sum(score["bert-precision"] for score in bert_scores) / len(bert_scores)
avg_recall = sum(score["bert-recall"] for score in bert_scores) / len(bert_scores)
avg_f1 = sum(score["bert-f1"] for score in bert_scores) / len(bert_scores)

print("\nAverage BERTScore:")
print("Average Precision:", avg_precision)
print("Average Recall:", avg_recall)
print("Average F1:", avg_f1)
# Out:
# Some weights of the model checkpoint at bert-base-chinese were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Average BERTScore:
# Average Precision: 0.6854258969426155
# Average Recall: 0.7297082269191741
# Average F1: 0.705667268037796

# %%
# input_text=''
import jieba
from rouge_chinese import Rouge

input_text = ds["test"][-1]["content"]
title = ds["test"][-1]["title"]

inputs = tokenizer("摘要生成: \n" + input_text + tokenizer.mask_token, return_tensors="pt")
inputs = tokenizer.build_inputs_for_generation(inputs, max_gen_length=64)
# inputs = inputs.to("cpu")
# 将输入张量移动到与模型相同的设备
inputs = {key: value.to(device) for key, value in inputs.items()}

output = model.generate(**inputs, max_new_tokens=64, eos_token_id=tokenizer.eop_token_id, do_sample=True)
print(tokenizer.decode(output[0].tolist()))

# 原始文本
text = tokenizer.decode(output[0].tolist())
# 提取数据
start_marker = '<|startofpiece|>'
end_marker = '<|endofpiece|>'
# 找到起始和结束位置
start_index = text.find(start_marker) + len(start_marker)
end_index = text.find(end_marker)
# 提取所需数据
extracted_data = text[start_index:end_index].strip()
# 打印结果
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# [CLS] 摘要生成: 中国证券网讯(记者严政)中国重工6月14日晚间公告称,公司日前接到控股股东中国船舶重工集团公司(简称“中船重工”)通知,中船重工拟对其自身相关业务进行调整,部分业务涉及到公司。其中,公司拟以持有的动力相关资产进行对外投资,参与中船重工拟打造的动力业务平台公司。公司上述对外投资的方案不构成重大资产重组,也不涉及公司发行股份。中国重工表示,目前方案还需进一步论证,存在不确定性。为保证公平信息披露,维护投资者利益,避免造成公司股价异常波动,经公司申请,自6月12日下午开市起公司股票停牌。同时公司将与中船重工保持密切联系,尽快确认是否进行上述事项,并于股票停牌之日起5个工作日内(含停牌当日)公告事项进展情况。[MASK]<|endoftext|> <|startofpiece|> 中国重工拟斥资14亿参建动力业务平台,包括参与中船重工打造的动力业务平台公司;或涉及公司公开增发等事项。 <|endofpiece|>

# %%
from rouge import Rouge
from transformers import BertTokenizer, BertForMaskedLM
from bert_score import BERTScorer
import jieba

# 定义预测和实际值
result = title
predict = extracted_data

# 加载BERT模型和tokenizer
model_name = './bert-base-chinese'
tokenizer_A = BertTokenizer.from_pretrained(model_name)
model_A = BertForMaskedLM.from_pretrained(model_name)
# 计算BERTScore
scorer = BERTScorer(model_type=model_name, num_layers=model_A.config.num_hidden_layers, batch_size=1)
P, R, F1 = scorer.score([predict], [result])

# 初始化 ROUGE 评分器
rouge = Rouge()
# 使用 jieba 进行分词
result_tokens = " ".join(jieba.cut(result))  # 实际值分词
predict_tokens = " ".join(jieba.cut(predict))  # 预测值分词


test=ds["test"][-1]["content"]

print('\n原文Content内容为:  '+test)


print('\n原文title内容为:  '+title)
print("\n")
print('文本摘要内容为:  '+extracted_data)
print("\n分词情况\n")
print(result_tokens)
print(predict_tokens)

# 将实际值和预测值放入列表
decode_preds = [predict_tokens]  # 预测值
decode_labels = [result_tokens]  # 实际值

# 计算 ROUGE 分数
scores = rouge.get_scores(decode_preds, decode_labels, avg=True)

# 提取 ROUGE 分数
rouge_scores = {
    "rouge-1": scores['rouge-1']['f'],
    "rouge-2": scores['rouge-2']['f'],
    "rouge-l": scores['rouge-l']['f'],
}

# 输出 ROUGE 和 BERTScore 结果
print("\nROUGE 分数:")
print(rouge_scores)

print("\nBERTScore:")
bert_scores = {
    "bert-precision": P.item(),
    "bert-recall": R.item(),
    "bert-f1": F1.item()
}
# 输出转换后的 BERTScore 结果
print(bert_scores)
# Out:
# Some weights of the model checkpoint at ./bert-base-chinese were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 原文Content内容为:  中国证券网讯(记者严政)中国重工6月14日晚间公告称,公司日前接到控股股东中国船舶重工集团公司(简称“中船重工”)通知,中船重工拟对其自身相关业务进行调整,部分业务涉及到公司。其中,公司拟以持有的动力相关资产进行对外投资,参与中船重工拟打造的动力业务平台公司。公司上述对外投资的方案不构成重大资产重组,也不涉及公司发行股份。中国重工表示,目前方案还需进一步论证,存在不确定性。为保证公平信息披露,维护投资者利益,避免造成公司股价异常波动,经公司申请,自6月12日下午开市起公司股票停牌。同时公司将与中船重工保持密切联系,尽快确认是否进行上述事项,并于股票停牌之日起5个工作日内(含停牌当日)公告事项进展情况。
#
# 原文title内容为:  中国重工拟以持有的动力相关资产进行对外投资,参与中船重工拟打造的动力业务平台公司,将继续停牌。
#
#
# 文本摘要内容为:  中国重工拟斥资14亿参建动力业务平台,包括参与中船重工打造的动力业务平台公司;或涉及公司公开增发等事项。
#
# 分词情况
#
# 中国 重工 拟以 持有 的 动力 相关 资产 进行 对外 投资 , 参与 中 船 重工 拟 打造 的 动力 业务 平台 公司 , 将 继续 停牌 。
# 中国 重工 拟 斥资 14 亿 参建 动力 业务 平台 , 包括 参与 中 船 重工 打造 的 动力 业务 平台 公司 ; 或 涉及 公司 公开 增发 等 事项 。
#
# ROUGE 分数:
# {'rouge-1': 0.559999995008, 'rouge-2': 0.3703703653772291, 'rouge-l': 0.5084745712841139}
#
# BERTScore:
# {'bert-precision': 0.8306502103805542, 'bert-recall': 0.8300982713699341, 'bert-f1': 0.8303741812705994}

# %% [markdown]
# Bert值计算

# %%
def generate_summary(input_text, tokenizer=tokenizer, model=model, device=device):
    # 生成摘要的输入
    inputs = tokenizer("摘要生成: \n" + input_text + tokenizer.mask_token, return_tensors="pt")
    inputs = tokenizer.build_inputs_for_generation(inputs, max_gen_length=64)

    # 将输入张量移动到与模型相同的设备
    inputs = {key: value.to(device) for key, value in inputs.items()}

    # 生成输出
    output = model.generate(**inputs, max_new_tokens=64, eos_token_id=tokenizer.eop_token_id, do_sample=True)

    # 解码生成的文本
    text = tokenizer.decode(output[0].tolist())
    # print(text)

    # 提取数据
    start_marker = '<|startofpiece|>'
    end_marker = '<|endofpiece|>'
    # 找到起始和结束位置
    start_index = text.find(start_marker) + len(start_marker)
    end_index = text.find(end_marker)
    # 提取所需数据
    extracted_data = text[start_index:end_index].strip()

    return extracted_data

# input_text = ds["test"][5]["content"]
# generate_summary(input_text)


input_text = ds["test"][5]["content"]
print('原文内容： '+input_text)
summary = generate_summary(input_text, tokenizer, model, device)
print('\n文本摘要内容为: ' + summary)
print('文本标题内容: ' + ds["test"][5]["title"])
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 原文内容： 记者7日从江苏省苏州市有关部门证实,该市一名初中副校长涉嫌泄露联考考题被停职,纪委已介入调查。今年4月,苏州市吴江区举行初三联考,震泽初级中学是联考学校之一,联考成绩将直接影响考生能否进入四星级高中(即重点高中)。就在考试前一天,考卷题目已在网上疯传,引发社会关注。据知情人士介绍,疑似震泽初级中学副校长将题目提前泄露给自己亲戚,然后这位亲戚又将题目进行了散播,导致题目最终被传到了网上。据苏州市吴江区教育局副局长沈正元介绍,泄题事件发生后,教育局于5月紧急推出了学校自主招生考试政策,以弥补泄题造成的不良后果。5月11日,教育局对涉嫌泄题违纪的震泽初级中学副校长作出停职处理,区纪委也已介入调查,教育部门会根据纪委处理意见进行相应处理。另据家长反映,泄题事件中一些“得题考生”出现在了震泽中学的保送名单里。对此,沈正元回应称,目前对涉嫌的涉事成年人进行了初步处理,纪委尚未作出明确处理意见,所以推优、自主招生等还按正常程序进行,因此出现了市民反映的疑似“得题考生”出现在名单中的情况。具体处理意见将在调查结果公布后作出,教育局将尽快进行相关调查工作,保障学生正当利益。(记者刘巍巍)
#
# 文本摘要内容为: 苏州吴江区一初中副校长泄考题,遭停职审查;学生因“得题”而获保送资格
# 文本标题内容: 苏州一初中副校长涉嫌泄露联考题目给亲戚,导致题目被传到网上,副校长停职被纪委调查;联考成绩直接影响考生能否进重点高中。

# %%
from ipywidgets import Button, Textarea, Output, HBox, VBox

import string
# 数字转换为汉字的字典
num_to_chinese = {
    "0": "零",
    "1": "一",
    "2": "二",
    "3": "三",
    "4": "四",
    "5": "五",
    "6": "六",
    "7": "七",
    "8": "八",
    "9": "九",
    "10": "十",
    "11": "十一",
    "12": "十二"
}
def remove_all_punctuation_and_convert_number_to_chinese(text):
    # 创建一个翻译表，用于将所有标点符号替换为空格
    translator = str.maketrans('', '', string.punctuation + "。"+"、"+"'"+"“"+"”"+"："+":"+" "+","+"，")
    # 使用翻译表去除文本中的所有标点符号
    text_without_punctuation = text.translate(translator)
    
    # 将文本中的数字转换为汉字
    for digit, chinese_character in num_to_chinese.items():
        text_without_punctuation = text_without_punctuation.replace(digit, chinese_character)
    
    return text_without_punctuation


import re
def contains_non_chinese_text(input_text):
    # 使用正则表达式匹配非中文字符
    non_chinese_pattern = re.compile(r'[^\u4e00-\u9fff]')  # 匹配不是中文字符的正则表达式
    match = non_chinese_pattern.search(input_text)

    if match:
        return True
    else:
        return False
def check_text_input(input_text):
    if len(input_text)<10:
        return 0
    
#     return 2

#     if not isinstance(input_text, str):
#         return 0
    if contains_non_chinese_text(input_text):
        return 1
    else:
        return 2
# # 示例用法
# check_text_input('这是一段文本内容')
# check_text_input('Hello World')
# check_text_input('1234')


# 定义一个简单的函数
def greet(b):
    input_text = remove_all_punctuation_and_convert_number_to_chinese(input_widget.value)
    output_num=check_text_input(input_text)  #数字输出 判断输入文本的类型
    if input_widget.value == '':
        text = '内容为空，请输入文本内容。'
    else:
        if output_num == 0:
            text = '输入不是文本，请输入文本内容。'
        elif output_num==1:
            text = '输入包含非中文字符，请输入中文文本。'
            # print( '输入包含非中文字符，请输入中文文本。')
            # text = generate_summary(input_widget.value)
        else:
            text = generate_summary(input_widget.value)
    
    output_widget.clear_output()
    with output_widget:
        print(f'{text}')

# 创建一个输出控件
output_widget = Output()

# 创建一个大的文本输入控件
input_widget = Textarea(
    placeholder='输入你的文本...',
    description='文本输入:',
    layout={'width': '600px', 'height': '300px'},  # 设置宽度和高度
    style={'overflow': 'auto'}  # 允许滚动
)

# 创建一个按钮
submit_button = Button(description="生成摘要")

# 将按钮的点击事件与 greet 函数关联
submit_button.on_click(greet)
# 增加间隔
# input_widget.layout.margin = '30px 30px 30px 30px'  # 上右下左的间距
# submit_button.layout.margin = '0 0 30px 0'  # 上右下左的间距
# 布局
ui = VBox([input_widget, submit_button, output_widget])

# 显示控件
ui
# Out:
# VBox(children=(Textarea(value='', description='文本输入:', layout=Layout(height='300px', width='600px'), placehold…
